# %% [markdown]
# #### Goal of the Project
#
# This Experiment is designed for you to practice and solve the activities that are based on the concepts in Multiple linear regression & Model Evaluation:

# %% [markdown]
# ### Problem Statement
#
# Build a model that is capable of predicting the relative humidity.
# The columns containing data for date, time air pollutants, temperature, relative humidity and absolute humidity. Also, evaluate the accuracy of your model by calculating the value of error metrics such as R-squared, MSE, RMSE, and MAE.

# %% [markdown]
# ---

# %% [markdown]
# ### List of Activities
#
# **Activity 1:** Analysing the Dataset
#
#
# **Activity 2:**  Train-Test Split
#
# **Activity 3:**  Model Training
#
# **Activity 4:** Model Prediction and Evaluation

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 1:  Analysing the Dataset
#
# - Create a Pandas DataFrame for **Airquality** dataset using the below link.
# https://raw.githubusercontent.com/smitha-ks/Notebooks/Datasets/AirQuality.csv
# This dataset consists of following columns:
#
# Date,Time,CO(GT),PT08.S1(CO),NMHC(GT),C6H6(GT),PT08.S2(NMHC),NOx(GT),PT08.S3(NOx),NO2(GT),PT08.S4(NO2),PT08.S5(O3),T,RH
#
#   **Dataset :** AirQuality.csv
#
# - Print the first five rows of the dataset. Check for null values and treat them accordingly.
#
# - Create a regression plot

# %%
# Import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
df=pd.read_csv("https://raw.githubusercontent.com/smitha-ks/Notebooks/Datasets/AirQuality.csv")

# %%
# Create data frame contain fields CO(GT),PT08.S1(CO),NMHC(GT),C6H6(GT),PT08.S2(NMHC),NOx(GT),PT08.S3(NOx),NO2(GT),PT08.S4(NO2),PT08.S5(O3),T,RH
#df=df.iloc[:,2:14]

# %%
# Print first five rows using head() function
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6         1360       150      11.9
# 1  3/10/2004  19:00:00     2.0         1292       112       9.4
# 2  3/10/2004  20:00:00     2.2         1402        88       9.0
# 3  3/10/2004  21:00:00     2.2         1376        80       9.2
# 4  3/10/2004  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
# Check if there are any null values. If any column has null values, treat them accordingly
print(df.isnull().sum())
# Out:
# Date                0
# Time                0
# CO(GT)              0
# PT08.S1(CO)         0
# NMHC(GT)            0
# C6H6(GT)            0
# PT08.S2(NMHC)       0
# NOx(GT)             0
# PT08.S3(NOx)        0
# NO2(GT)             0
# PT08.S4(NO2)        0
# PT08.S5(O3)         0
# T                   0
# RH                  0
# AH                  0
# Unnamed: 15      9357
# Unnamed: 16      9357
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 2: Train-Test Split
#
# We have to determine the effect of `age` on insurance charges. Thus, `age` is the feature variable and `charges` is the target variable.
#
# Split the dataset into training set and test set such that the training set contains 67% of the instances and the remaining instances will become the test set.

# %%
# Split the DataFrame into the training and test sets.
x=df.iloc[:,2:13]
y=df.iloc[:,13:14]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (6269, 11) (3088, 11) (6269, 1) (3088, 1)

# %% [markdown]
# **Activity 3 : Model Training**

# %%
#create the object of LinearRegression
lr=LinearRegression()

# Call the 'fit()' function
lr.fit(x_train,y_train)


# Print the slope and intercept values
print(lr.intercept_)
print(lr.coef_)
# Out:
# [149.19213562]
# [[ 0.00772578  0.01119848 -0.01233241  3.43625317 -0.18755605  0.02324046
#   -0.03516458 -0.04204686  0.05426291  0.00421347 -1.51878409]]

# %% [markdown]
# #### Activity 4: Model Prediction and Evaluation
#
# Predict the values for both training and test sets by calling the `predict()` function on the LinearRegression object. Also, calculate the $R^2$, MSE, RMSE and MAE values to evaluate the accuracy of your model.

# %%
# Predict the target variable values for both training set and test set
train_pred=lr.predict(x_train)
test_pred=lr.predict(x_test)

#print performance measure values
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
print("Training performance\n")
print("R.squared:\t",r2_score(y_train,train_pred))
print("Mean squared error:\t",mean_squared_error(y_train,train_pred))
print("Root mean squared error:\t",np.sqrt(mean_squared_error(y_train,train_pred)))
print("Mean absolute erroe:\t",mean_absolute_error(y_train,train_pred))
# Out:
# Training performance
#
# R.squared:	 0.964947209689305
# Mean squared error:	 92.58734245788855
# Root mean squared error:	 9.622231677624924
# Mean absolute erroe:	 7.281082769640301
