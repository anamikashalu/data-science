# %%
import tensorflow as tf
from keras import datasets,layers,models
import matplotlib

# %%
#compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
#print a summary of the models architecture
model.summary()

# %%
#train the model
learn=model.fit(train_images, train_labels, epochs=5, validation_data=(test_images, test_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5dc978384219> in <cell line: 2>()
#       1 #train the model
# ----> 2 learn=model.fit(train_images, train_labels, epochs=5, validation_data=(test_images, test_labels))
#
# NameError: name 'model' is not defined
